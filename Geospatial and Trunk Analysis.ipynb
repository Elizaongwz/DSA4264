# %% [markdown]
# # Geospatial Data

# %%
import geopandas
import re
import pandas as pd
import folium
import requests
from flask import Flask, jsonify
import time
from tqdm import tqdm
import matplotlib.pyplot as plt
pd.options.mode.chained_assignment = None

# %% [markdown]
# ## Train stations in Singapore

# %%
train_stations = geopandas.read_file("TrainStation_Jul2024/repaired_shapefile.shp")
# Out:
# /Users/elizaong/Downloads/DSA4264/venv/lib/python3.11/site-packages/pyogrio/raw.py:198: RuntimeWarning: TrainStation_Jul2024/repaired_shapefile.shp contains polygon(s) with rings with invalid winding order. Autocorrecting them, but that shapefile should be corrected using ogr2ogr for example.
#   return ogr_read(

# %%
MP19_Subzone_Folium_Train_Stations = folium.Map(location = (1.359394, 103.814301), zoom_start = 12)
folium.GeoJson(train_stations, name = "MP19 Subzones").add_to(MP19_Subzone_Folium_Train_Stations)
MP19_Subzone_Folium_Train_Stations
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## Bus stops in Singapore

# %%
bus_stops = geopandas.read_file("BusStopLocation_Jul2024/BusStop.shp")

# %%
MP19_Subzone_Folium_Bus_Stops = folium.Map(location = (1.359394, 103.814301), zoom_start = 12)
folium.GeoJson(bus_stops, name = "MP19 Subzones").add_to(MP19_Subzone_Folium_Bus_Stops)
MP19_Subzone_Folium_Bus_Stops
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
